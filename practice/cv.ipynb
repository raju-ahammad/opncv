# %%
import numpy
import matplotlib.pyplot as plt 
import cv2

# %%
img = cv2.imread('img/tony.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (538, 620, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('img/tony.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
resize = cv2.resize(fix_img,(950, 600))

# %%
plt.imshow(resize)

# %%
flip = cv2.flip(fix_img, 0)
plt.imshow(flip)

# %%
cv2.imwrite('new.jpg',fix_img)
# Out:
# True

# %%
plt.imshow(fix_img)
